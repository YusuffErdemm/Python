# %%
class Dosya():

    def __init__(self,dosya_ismi):

        with open(dosya_ismi,"r",encoding = "utf-8") as file:

            dosya_icerigi = file.read()
            kelimeler = dosya_icerigi.split()

            self.sade_kelimeler = list()

            for kelime in kelimeler:
                kelime = kelime.strip()
                kelime = kelime.strip(".")
                kelime = kelime.strip("\n")

                self.sade_kelimeler.append(kelime)
    def kelime_bul(self,aranan):

        konumlar = list()
        say = 1
        for kelime in self.sade_kelimeler:
            if (kelime == aranan ):
                konumlar.append(say)

            say += 1

        if (len(konumlar) == 0):
            print("Dosyada böyle bir kelime bulunmuyor...")
        else:

            print("{} kelimesi dosyada şuralarda geçiyor. \n{}".format(aranan,konumlar))



    def kelime_histogramı(self):

        kelime_frekansı = dict()
        kelime_kümesi = set()

        for kelime in self.sade_kelimeler:
            kelime_kümesi.add(kelime)
            if (kelime in kelime_frekansı):
                kelime_frekansı[kelime] += 1
            else:
                kelime_frekansı[kelime] = 1
        print("Kelimelerin Frekansı........................")
        for i, j in kelime_frekansı.items():
            print("{} kelimesi metinde {} defa geçiyor.".format(i, j))

        print("Tüm Kelimeler")
        for i in kelime_kümesi:
            print(i)
            print("*************************************")


dosya =  Dosya("text.txt")
print("""****************

Dosya İşlemleri 

1. Tüm kelime frekansını öğren

2. Kelime Ara

Çıkmak için 'q' ya basın.

""")
while True:
    işlem = input("İşlem:")

    if (işlem == "q"):
        print("Programdan Çıkılıyor....")
        break
    elif (işlem == "1"):
        dosya.kelime_histogramı()
    elif (işlem == "2"):
        kelime = input("Hangi kelimeyi arıyorsunuz ?")
        dosya.kelime_bul(kelime)
    else:
        print("Geçersiz İşlem...")
# Out:
# ****************
#
# Dosya İşlemleri
#
# 1. Tüm kelime frekansını öğren
#
# 2. Kelime Ara
#
# Çıkmak için 'q' ya basın.
#
#
# İşlem:1
# Kelimelerin Frekansı........................
# Dostoyevski kelimesi metinde 1 defa geçiyor.
# Rusya’da kelimesi metinde 1 defa geçiyor.
# yaşanan kelimesi metinde 1 defa geçiyor.
# siyasi kelimesi metinde 1 defa geçiyor.
# ve kelimesi metinde 15 defa geçiyor.
# ekonomik kelimesi metinde 1 defa geçiyor.
# olaylar kelimesi metinde 1 defa geçiyor.
# sonrasında kelimesi metinde 1 defa geçiyor.
# gözlemlediği kelimesi metinde 1 defa geçiyor.
# hayatlardan kelimesi metinde 1 defa geçiyor.
# esinlenerek kelimesi metinde 1 defa geçiyor.
# 1866 kelimesi metinde 1 defa geçiyor.
# yılında kelimesi metinde 1 defa geçiyor.
# yazdığı kelimesi metinde 1 defa geçiyor.
# eser kelimesi metinde 2 defa geçiyor.
# ilk kelimesi metinde 1 defa geçiyor.
# olarak kelimesi metinde 1 defa geçiyor.
# Rus kelimesi metinde 1 defa geçiyor.
# Habercisi kelimesi metinde 1 defa geçiyor.
# isimli kelimesi metinde 1 defa geçiyor.
# edebiyat kelimesi metinde 1 defa geçiyor.
# dergisinde kelimesi metinde 1 defa geçiyor.
# yayınlanmıştır kelimesi metinde 1 defa geçiyor.
# Büyük kelimesi metinde 1 defa geçiyor.
# beğeni kelimesi metinde 1 defa geçiyor.
# toplayan kelimesi metinde 1 defa geçiyor.
# daha kelimesi metinde 7 defa geçiyor.
# sonra kelimesi metinde 1 defa geçiyor.
# kitap kelimesi metinde 2 defa geçiyor.
# haline kelimesi metinde 1 defa geçiyor.
# getirilmiş kelimesi metinde 1 defa geçiyor.
# o kelimesi metinde 2 defa geçiyor.
# günden kelimesi metinde 1 defa geçiyor.
# beri kelimesi metinde 1 defa geçiyor.
# birçok kelimesi metinde 2 defa geçiyor.
# sinema kelimesi metinde 1 defa geçiyor.
# filmine kelimesi metinde 1 defa geçiyor.
# konu kelimesi metinde 1 defa geçiyor.
# olmuştur kelimesi metinde 1 defa geçiyor.
# Suç kelimesi metinde 1 defa geçiyor.
# Ceza kelimesi metinde 1 defa geçiyor.
# Dostoyevski’nin kelimesi metinde 1 defa geçiyor.
# başyapıtı kelimesi metinde 1 defa geçiyor.
# sayılır kelimesi metinde 1 defa geçiyor.
# Kitabın kelimesi metinde 1 defa geçiyor.
# başkahramanı kelimesi metinde 1 defa geçiyor.
# olan kelimesi metinde 4 defa geçiyor.
# Raskolnikov kelimesi metinde 5 defa geçiyor.
# Rusya’nın kelimesi metinde 1 defa geçiyor.
# St kelimesi metinde 2 defa geçiyor.
# Petersburg kelimesi metinde 2 defa geçiyor.
# şehrinde kelimesi metinde 2 defa geçiyor.
# hukuk kelimesi metinde 2 defa geçiyor.
# fakültesinde kelimesi metinde 1 defa geçiyor.
# okuyan kelimesi metinde 1 defa geçiyor.
# başarılı kelimesi metinde 1 defa geçiyor.
# bir kelimesi metinde 5 defa geçiyor.
# öğrencidir kelimesi metinde 1 defa geçiyor.
# Fakir kelimesi metinde 1 defa geçiyor.
# olduğu kelimesi metinde 1 defa geçiyor.
# için kelimesi metinde 2 defa geçiyor.
# hayatını kelimesi metinde 1 defa geçiyor.
# öğretimini kelimesi metinde 1 defa geçiyor.
# devam kelimesi metinde 1 defa geçiyor.
# ettirmekte kelimesi metinde 1 defa geçiyor.
# oldukça kelimesi metinde 1 defa geçiyor.
# zorlanır kelimesi metinde 1 defa geçiyor.
# fakültesini kelimesi metinde 1 defa geçiyor.
# bırakmak kelimesi metinde 1 defa geçiyor.
# zorunda kelimesi metinde 1 defa geçiyor.
# kalır kelimesi metinde 1 defa geçiyor.
# Yaşadığı kelimesi metinde 1 defa geçiyor.
# hayat kelimesi metinde 1 defa geçiyor.
# iç kelimesi metinde 3 defa geçiyor.
# dünyasında kelimesi metinde 1 defa geçiyor.
# kalıcı kelimesi metinde 1 defa geçiyor.
# zararlar kelimesi metinde 1 defa geçiyor.
# vermeye kelimesi metinde 1 defa geçiyor.
# başlar kelimesi metinde 2 defa geçiyor.
# kendi kelimesi metinde 1 defa geçiyor.
# içinde kelimesi metinde 1 defa geçiyor.
# çelişkiye kelimesi metinde 1 defa geçiyor.
# düşmeye kelimesi metinde 1 defa geçiyor.
# Okumak kelimesi metinde 1 defa geçiyor.
# geldiği kelimesi metinde 1 defa geçiyor.
# kirasını kelimesi metinde 1 defa geçiyor.
# ödeyemez kelimesi metinde 1 defa geçiyor.
# Yakınlarda kelimesi metinde 1 defa geçiyor.
# bulunan kelimesi metinde 1 defa geçiyor.
# hiç kelimesi metinde 1 defa geçiyor.
# kimsenin kelimesi metinde 1 defa geçiyor.
# sevmediği kelimesi metinde 1 defa geçiyor.
# tefeci kelimesi metinde 2 defa geçiyor.
# kadına kelimesi metinde 1 defa geçiyor.
# giderek kelimesi metinde 1 defa geçiyor.
# saatini kelimesi metinde 1 defa geçiyor.
# satar kelimesi metinde 1 defa geçiyor.
# Karşılığında kelimesi metinde 1 defa geçiyor.
# aldığı kelimesi metinde 1 defa geçiyor.
# para kelimesi metinde 1 defa geçiyor.
# ile kelimesi metinde 2 defa geçiyor.
# de kelimesi metinde 2 defa geçiyor.
# meyhaneye kelimesi metinde 1 defa geçiyor.
# gider kelimesi metinde 3 defa geçiyor.
# Bir kelimesi metinde 2 defa geçiyor.
# taraftan kelimesi metinde 2 defa geçiyor.
# içerken kelimesi metinde 1 defa geçiyor.
# diğer kelimesi metinde 1 defa geçiyor.
# meyhanedeki kelimesi metinde 1 defa geçiyor.
# insanların kelimesi metinde 1 defa geçiyor.
# hayatları kelimesi metinde 1 defa geçiyor.
# içini kelimesi metinde 1 defa geçiyor.
# da kelimesi metinde 5 defa geçiyor.
# karartır kelimesi metinde 1 defa geçiyor.
# Fakirler kelimesi metinde 1 defa geçiyor.
# zenginler kelimesi metinde 1 defa geçiyor.
# arasında kelimesi metinde 1 defa geçiyor.
# acımasız kelimesi metinde 1 defa geçiyor.
# ayrıma kelimesi metinde 1 defa geçiyor.
# anlam kelimesi metinde 1 defa geçiyor.
# veremez kelimesi metinde 1 defa geçiyor.
# içindeki kelimesi metinde 2 defa geçiyor.
# çatışmalara kelimesi metinde 1 defa geçiyor.
# fazla kelimesi metinde 2 defa geçiyor.
# dayanamaz kelimesi metinde 2 defa geçiyor.
# şeytana kelimesi metinde 1 defa geçiyor.
# kulak kelimesi metinde 1 defa geçiyor.
# verek kelimesi metinde 1 defa geçiyor.
# eline kelimesi metinde 1 defa geçiyor.
# balta kelimesi metinde 1 defa geçiyor.
# alarak kelimesi metinde 2 defa geçiyor.
# kadının kelimesi metinde 4 defa geçiyor.
# evine kelimesi metinde 1 defa geçiyor.
# Baltayı kelimesi metinde 1 defa geçiyor.
# kafasına kelimesi metinde 1 defa geçiyor.
# indirerek kelimesi metinde 1 defa geçiyor.
# onu kelimesi metinde 3 defa geçiyor.
# orada kelimesi metinde 1 defa geçiyor.
# öldürür kelimesi metinde 2 defa geçiyor.
# Tam kelimesi metinde 1 defa geçiyor.
# bu kelimesi metinde 2 defa geçiyor.
# sırada kelimesi metinde 1 defa geçiyor.
# yaşlı kelimesi metinde 1 defa geçiyor.
# kız kelimesi metinde 1 defa geçiyor.
# kardeşi kelimesi metinde 1 defa geçiyor.
# gelir kelimesi metinde 1 defa geçiyor.
# anda kelimesi metinde 1 defa geçiyor.
# Tefeci kelimesi metinde 1 defa geçiyor.
# kötülüğünün kelimesi metinde 1 defa geçiyor.
# yanında kelimesi metinde 1 defa geçiyor.
# masumun kelimesi metinde 1 defa geçiyor.
# ölmesi kelimesi metinde 1 defa geçiyor.
# pek kelimesi metinde 1 defa geçiyor.
# önemli kelimesi metinde 1 defa geçiyor.
# değildir kelimesi metinde 1 defa geçiyor.
# Ne kelimesi metinde 1 defa geçiyor.
# yapacağını kelimesi metinde 1 defa geçiyor.
# bilmeden kelimesi metinde 1 defa geçiyor.
# birkaç kelimesi metinde 1 defa geçiyor.
# altını kelimesi metinde 1 defa geçiyor.
# oradan kelimesi metinde 1 defa geçiyor.
# uzaklaştı kelimesi metinde 1 defa geçiyor.
# İşlediği kelimesi metinde 1 defa geçiyor.
# cinayet kelimesi metinde 1 defa geçiyor.
# sonrası kelimesi metinde 1 defa geçiyor.
# Raskolnikov’un kelimesi metinde 2 defa geçiyor.
# durumu kelimesi metinde 1 defa geçiyor.
# kötüye kelimesi metinde 3 defa geçiyor.
# zamanlar kelimesi metinde 1 defa geçiyor.
# çelişkiler kelimesi metinde 1 defa geçiyor.
# yaşamasına kelimesi metinde 1 defa geçiyor.
# neden kelimesi metinde 1 defa geçiyor.
# şeytan kelimesi metinde 1 defa geçiyor.
# ortadan kelimesi metinde 1 defa geçiyor.
# kaybolmuş kelimesi metinde 1 defa geçiyor.
# fakat kelimesi metinde 1 defa geçiyor.
# ondan kelimesi metinde 1 defa geçiyor.
# kötü kelimesi metinde 1 defa geçiyor.
# vicdan kelimesi metinde 1 defa geçiyor.
# azabı kelimesi metinde 1 defa geçiyor.
# gelmiştir kelimesi metinde 1 defa geçiyor.
# Duyduğu kelimesi metinde 1 defa geçiyor.
# pişmanlıklar kelimesi metinde 1 defa geçiyor.
# çekişmeler kelimesi metinde 1 defa geçiyor.
# Raskolnikov’u kelimesi metinde 1 defa geçiyor.
# iyice kelimesi metinde 1 defa geçiyor.
# bitkin kelimesi metinde 1 defa geçiyor.
# düşürür kelimesi metinde 1 defa geçiyor.
# hastalanır kelimesi metinde 1 defa geçiyor.
# İmdadına kelimesi metinde 1 defa geçiyor.
# en kelimesi metinde 2 defa geçiyor.
# yakın kelimesi metinde 1 defa geçiyor.
# arkadaşı kelimesi metinde 1 defa geçiyor.
# Razumikin kelimesi metinde 1 defa geçiyor.
# yetişir kelimesi metinde 1 defa geçiyor.
# Ona kelimesi metinde 1 defa geçiyor.
# destek kelimesi metinde 1 defa geçiyor.
# olur, kelimesi metinde 1 defa geçiyor.
# doktor kelimesi metinde 1 defa geçiyor.
# bulur kelimesi metinde 1 defa geçiyor.
# elinden kelimesi metinde 1 defa geçiyor.
# gelen kelimesi metinde 1 defa geçiyor.
# her kelimesi metinde 1 defa geçiyor.
# şeyi kelimesi metinde 1 defa geçiyor.
# yapar kelimesi metinde 1 defa geçiyor.
# giden kelimesi metinde 1 defa geçiyor.
# durumuna kelimesi metinde 1 defa geçiyor.
# şüphecilik kelimesi metinde 1 defa geçiyor.
# korku kelimesi metinde 1 defa geçiyor.
# eklenir kelimesi metinde 1 defa geçiyor.
# Sürekli kelimesi metinde 1 defa geçiyor.
# birilerinin kelimesi metinde 2 defa geçiyor.
# izlediğini kelimesi metinde 1 defa geçiyor.
# düşünür kelimesi metinde 2 defa geçiyor.
# Cinayeti kelimesi metinde 1 defa geçiyor.
# gördüğü kelimesi metinde 1 defa geçiyor.
# yada kelimesi metinde 1 defa geçiyor.
# azından kelimesi metinde 1 defa geçiyor.
# onun kelimesi metinde 2 defa geçiyor.
# yaptığını kelimesi metinde 1 defa geçiyor.
# bildiğini kelimesi metinde 1 defa geçiyor.
# Bu kelimesi metinde 1 defa geçiyor.
# tedirginlik kelimesi metinde 1 defa geçiyor.
# durumunu kelimesi metinde 1 defa geçiyor.
# sürükler kelimesi metinde 1 defa geçiyor.
# duruma kelimesi metinde 1 defa geçiyor.
# işlediği kelimesi metinde 1 defa geçiyor.
# cinayeti kelimesi metinde 1 defa geçiyor.
# Sonya’ya kelimesi metinde 1 defa geçiyor.
# anlatır kelimesi metinde 1 defa geçiyor.
# Ardından kelimesi metinde 1 defa geçiyor.
# polise kelimesi metinde 1 defa geçiyor.
# teslim kelimesi metinde 1 defa geçiyor.
# olur kelimesi metinde 1 defa geçiyor.
# cezasını kelimesi metinde 1 defa geçiyor.
# çekmek kelimesi metinde 1 defa geçiyor.
# üzere kelimesi metinde 1 defa geçiyor.
# hapse kelimesi metinde 1 defa geçiyor.
# gönderilir kelimesi metinde 1 defa geçiyor.
# Tüm Kelimeler
# en
# *************************************
# pek
# *************************************
# Fakirler
# *************************************
# öğrencidir
# *************************************
# başyapıtı
# *************************************
# yaşlı
# *************************************
# ortadan
# *************************************
# çatışmalara
# *************************************
# cinayet
# *************************************
# yapar
# *************************************
# Dostoyevski’nin
# *************************************
# Ne
# *************************************
# çelişkiler
# *************************************
# altını
# *************************************
# anlam
# *************************************
# fakültesini
# *************************************
# başarılı
# *************************************
# taraftan
# *************************************
# yapacağını
# *************************************
# Yakınlarda
# *************************************
# Ceza
# *************************************
# önemli
# *************************************
# Ona
# *************************************
# bu
# *************************************
# duruma
# *************************************
# yanında
# *************************************
# ondan
# *************************************
# üzere
# *************************************
# getirilmiş
# *************************************
# öğretimini
# *************************************
# bırakmak
# *************************************
# Baltayı
# *************************************
# ölmesi
# *************************************
# kötülüğünün
# *************************************
# meyhanedeki
# *************************************
# bildiğini
# *************************************
# düşünür
# *************************************
# geldiği
# *************************************
# diğer
# *************************************
# hastalanır
# *************************************
# çekişmeler
# *************************************
# kötü
# *************************************
# Ardından
# *************************************
# Petersburg
# *************************************
# durumu
# *************************************
# çekmek
# *************************************
# hiç
# *************************************
# birçok
# *************************************
# hayatını
# *************************************
# sinema
# *************************************
# bulur
# *************************************
# için
# *************************************
# beğeni
# *************************************
# veremez
# *************************************
# olur
# *************************************
# kitap
# *************************************
# fakültesinde
# *************************************
# o
# *************************************
# Dostoyevski
# *************************************
# düşürür
# *************************************
# bulunan
# *************************************
# kafasına
# *************************************
# ve
# *************************************
# kulak
# *************************************
# yayınlanmıştır
# *************************************
# Rusya’nın
# *************************************
# sürükler
# *************************************
# hukuk
# *************************************
# dergisinde
# *************************************
# zararlar
# *************************************
# İmdadına
# *************************************
# Duyduğu
# *************************************
# şeyi
# *************************************
# isimli
# *************************************
# Bir
# *************************************
# orada
# *************************************
# Karşılığında
# *************************************
# birilerinin
# *************************************
# durumunu
# *************************************
# gönderilir
# *************************************
# korku
# *************************************
# kadının
# *************************************
# siyasi
# *************************************
# içerken
# *************************************
# Rus
# *************************************
# gözlemlediği
# *************************************
# Büyük
# *************************************
# sırada
# *************************************
# Okumak
# *************************************
# yakın
# *************************************
# pişmanlıklar
# *************************************
# eline
# *************************************
# ayrıma
# *************************************
# hayatlardan
# *************************************
# kalıcı
# *************************************
# olaylar
# *************************************
# alarak
# *************************************
# filmine
# *************************************
# sonrası
# *************************************
# durumuna
# *************************************
# konu
# *************************************
# iç
# *************************************
# okuyan
# *************************************
# Rusya’da
# *************************************
# ödeyemez
# *************************************
# Raskolnikov
# *************************************
# eser
# *************************************
# vermeye
# *************************************
# başkahramanı
# *************************************
# aldığı
# *************************************
# devam
# *************************************
# azabı
# *************************************
# İşlem:1
# Kelimelerin Frekansı........................
# Dostoyevski kelimesi metinde 1 defa geçiyor.
# Rusya’da kelimesi metinde 1 defa geçiyor.
# yaşanan kelimesi metinde 1 defa geçiyor.
# siyasi kelimesi metinde 1 defa geçiyor.
# ve kelimesi metinde 15 defa geçiyor.
# ekonomik kelimesi metinde 1 defa geçiyor.
# olaylar kelimesi metinde 1 defa geçiyor.
# sonrasında kelimesi metinde 1 defa geçiyor.
# gözlemlediği kelimesi metinde 1 defa geçiyor.
# hayatlardan kelimesi metinde 1 defa geçiyor.
# esinlenerek kelimesi metinde 1 defa geçiyor.
# 1866 kelimesi metinde 1 defa geçiyor.
# yılında kelimesi metinde 1 defa geçiyor.
# yazdığı kelimesi metinde 1 defa geçiyor.
# eser kelimesi metinde 2 defa geçiyor.
# ilk kelimesi metinde 1 defa geçiyor.
# olarak kelimesi metinde 1 defa geçiyor.
# Rus kelimesi metinde 1 defa geçiyor.
# Habercisi kelimesi metinde 1 defa geçiyor.
# isimli kelimesi metinde 1 defa geçiyor.
# edebiyat kelimesi metinde 1 defa geçiyor.
# dergisinde kelimesi metinde 1 defa geçiyor.
# yayınlanmıştır kelimesi metinde 1 defa geçiyor.
# Büyük kelimesi metinde 1 defa geçiyor.
# beğeni kelimesi metinde 1 defa geçiyor.
# toplayan kelimesi metinde 1 defa geçiyor.
# daha kelimesi metinde 7 defa geçiyor.
# sonra kelimesi metinde 1 defa geçiyor.
# kitap kelimesi metinde 2 defa geçiyor.
# haline kelimesi metinde 1 defa geçiyor.
# getirilmiş kelimesi metinde 1 defa geçiyor.
# o kelimesi metinde 2 defa geçiyor.
# günden kelimesi metinde 1 defa geçiyor.
# beri kelimesi metinde 1 defa geçiyor.
# birçok kelimesi metinde 2 defa geçiyor.
# sinema kelimesi metinde 1 defa geçiyor.
# filmine kelimesi metinde 1 defa geçiyor.
# konu kelimesi metinde 1 defa geçiyor.
# olmuştur kelimesi metinde 1 defa geçiyor.
# Suç kelimesi metinde 1 defa geçiyor.
# Ceza kelimesi metinde 1 defa geçiyor.
# Dostoyevski’nin kelimesi metinde 1 defa geçiyor.
# başyapıtı kelimesi metinde 1 defa geçiyor.
# sayılır kelimesi metinde 1 defa geçiyor.
# Kitabın kelimesi metinde 1 defa geçiyor.
# başkahramanı kelimesi metinde 1 defa geçiyor.
# olan kelimesi metinde 4 defa geçiyor.
# Raskolnikov kelimesi metinde 5 defa geçiyor.
# Rusya’nın kelimesi metinde 1 defa geçiyor.
# St kelimesi metinde 2 defa geçiyor.
# Petersburg kelimesi metinde 2 defa geçiyor.
# şehrinde kelimesi metinde 2 defa geçiyor.
# hukuk kelimesi metinde 2 defa geçiyor.
# fakültesinde kelimesi metinde 1 defa geçiyor.
# okuyan kelimesi metinde 1 defa geçiyor.
# başarılı kelimesi metinde 1 defa geçiyor.
# bir kelimesi metinde 5 defa geçiyor.
# öğrencidir kelimesi metinde 1 defa geçiyor.
# Fakir kelimesi metinde 1 defa geçiyor.
# olduğu kelimesi metinde 1 defa geçiyor.
# için kelimesi metinde 2 defa geçiyor.
# hayatını kelimesi metinde 1 defa geçiyor.
# öğretimini kelimesi metinde 1 defa geçiyor.
# devam kelimesi metinde 1 defa geçiyor.
# ettirmekte kelimesi metinde 1 defa geçiyor.
# oldukça kelimesi metinde 1 defa geçiyor.
# zorlanır kelimesi metinde 1 defa geçiyor.
# fakültesini kelimesi metinde 1 defa geçiyor.
# bırakmak kelimesi metinde 1 defa geçiyor.
# zorunda kelimesi metinde 1 defa geçiyor.
# kalır kelimesi metinde 1 defa geçiyor.
# Yaşadığı kelimesi metinde 1 defa geçiyor.
# hayat kelimesi metinde 1 defa geçiyor.
# iç kelimesi metinde 3 defa geçiyor.
# dünyasında kelimesi metinde 1 defa geçiyor.
# kalıcı kelimesi metinde 1 defa geçiyor.
# zararlar kelimesi metinde 1 defa geçiyor.
# vermeye kelimesi metinde 1 defa geçiyor.
# başlar kelimesi metinde 2 defa geçiyor.
# kendi kelimesi metinde 1 defa geçiyor.
# içinde kelimesi metinde 1 defa geçiyor.
# çelişkiye kelimesi metinde 1 defa geçiyor.
# düşmeye kelimesi metinde 1 defa geçiyor.
# Okumak kelimesi metinde 1 defa geçiyor.
# geldiği kelimesi metinde 1 defa geçiyor.
# kirasını kelimesi metinde 1 defa geçiyor.
# ödeyemez kelimesi metinde 1 defa geçiyor.
# Yakınlarda kelimesi metinde 1 defa geçiyor.
# bulunan kelimesi metinde 1 defa geçiyor.
# hiç kelimesi metinde 1 defa geçiyor.
# kimsenin kelimesi metinde 1 defa geçiyor.
# sevmediği kelimesi metinde 1 defa geçiyor.
# tefeci kelimesi metinde 2 defa geçiyor.
# kadına kelimesi metinde 1 defa geçiyor.
# giderek kelimesi metinde 1 defa geçiyor.
# saatini kelimesi metinde 1 defa geçiyor.
# satar kelimesi metinde 1 defa geçiyor.
# Karşılığında kelimesi metinde 1 defa geçiyor.
# aldığı kelimesi metinde 1 defa geçiyor.
# para kelimesi metinde 1 defa geçiyor.
# ile kelimesi metinde 2 defa geçiyor.
# de kelimesi metinde 2 defa geçiyor.
# meyhaneye kelimesi metinde 1 defa geçiyor.
# gider kelimesi metinde 3 defa geçiyor.
# Bir kelimesi metinde 2 defa geçiyor.
# taraftan kelimesi metinde 2 defa geçiyor.
# içerken kelimesi metinde 1 defa geçiyor.
# diğer kelimesi metinde 1 defa geçiyor.
# meyhanedeki kelimesi metinde 1 defa geçiyor.
# insanların kelimesi metinde 1 defa geçiyor.
# hayatları kelimesi metinde 1 defa geçiyor.
# içini kelimesi metinde 1 defa geçiyor.
# da kelimesi metinde 5 defa geçiyor.
# karartır kelimesi metinde 1 defa geçiyor.
# Fakirler kelimesi metinde 1 defa geçiyor.
# zenginler kelimesi metinde 1 defa geçiyor.
# arasında kelimesi metinde 1 defa geçiyor.
# acımasız kelimesi metinde 1 defa geçiyor.
# ayrıma kelimesi metinde 1 defa geçiyor.
# anlam kelimesi metinde 1 defa geçiyor.
# veremez kelimesi metinde 1 defa geçiyor.
# içindeki kelimesi metinde 2 defa geçiyor.
# çatışmalara kelimesi metinde 1 defa geçiyor.
# fazla kelimesi metinde 2 defa geçiyor.
# dayanamaz kelimesi metinde 2 defa geçiyor.
# şeytana kelimesi metinde 1 defa geçiyor.
# kulak kelimesi metinde 1 defa geçiyor.
# verek kelimesi metinde 1 defa geçiyor.
# eline kelimesi metinde 1 defa geçiyor.
# balta kelimesi metinde 1 defa geçiyor.
# alarak kelimesi metinde 2 defa geçiyor.
# kadının kelimesi metinde 4 defa geçiyor.
# evine kelimesi metinde 1 defa geçiyor.
# Baltayı kelimesi metinde 1 defa geçiyor.
# kafasına kelimesi metinde 1 defa geçiyor.
# indirerek kelimesi metinde 1 defa geçiyor.
# onu kelimesi metinde 3 defa geçiyor.
# orada kelimesi metinde 1 defa geçiyor.
# öldürür kelimesi metinde 2 defa geçiyor.
# Tam kelimesi metinde 1 defa geçiyor.
# bu kelimesi metinde 2 defa geçiyor.
# sırada kelimesi metinde 1 defa geçiyor.
# yaşlı kelimesi metinde 1 defa geçiyor.
# kız kelimesi metinde 1 defa geçiyor.
# kardeşi kelimesi metinde 1 defa geçiyor.
# gelir kelimesi metinde 1 defa geçiyor.
# anda kelimesi metinde 1 defa geçiyor.
# Tefeci kelimesi metinde 1 defa geçiyor.
# kötülüğünün kelimesi metinde 1 defa geçiyor.
# yanında kelimesi metinde 1 defa geçiyor.
# masumun kelimesi metinde 1 defa geçiyor.
# ölmesi kelimesi metinde 1 defa geçiyor.
# pek kelimesi metinde 1 defa geçiyor.
# önemli kelimesi metinde 1 defa geçiyor.
# değildir kelimesi metinde 1 defa geçiyor.
# Ne kelimesi metinde 1 defa geçiyor.
# yapacağını kelimesi metinde 1 defa geçiyor.
# bilmeden kelimesi metinde 1 defa geçiyor.
# birkaç kelimesi metinde 1 defa geçiyor.
# altını kelimesi metinde 1 defa geçiyor.
# oradan kelimesi metinde 1 defa geçiyor.
# uzaklaştı kelimesi metinde 1 defa geçiyor.
# İşlediği kelimesi metinde 1 defa geçiyor.
# cinayet kelimesi metinde 1 defa geçiyor.
# sonrası kelimesi metinde 1 defa geçiyor.
# Raskolnikov’un kelimesi metinde 2 defa geçiyor.
# durumu kelimesi metinde 1 defa geçiyor.
# kötüye kelimesi metinde 3 defa geçiyor.
# zamanlar kelimesi metinde 1 defa geçiyor.
# çelişkiler kelimesi metinde 1 defa geçiyor.
# yaşamasına kelimesi metinde 1 defa geçiyor.
# neden kelimesi metinde 1 defa geçiyor.
# şeytan kelimesi metinde 1 defa geçiyor.
# ortadan kelimesi metinde 1 defa geçiyor.
# kaybolmuş kelimesi metinde 1 defa geçiyor.
# fakat kelimesi metinde 1 defa geçiyor.
# ondan kelimesi metinde 1 defa geçiyor.
# kötü kelimesi metinde 1 defa geçiyor.
# vicdan kelimesi metinde 1 defa geçiyor.
# azabı kelimesi metinde 1 defa geçiyor.
# gelmiştir kelimesi metinde 1 defa geçiyor.
# Duyduğu kelimesi metinde 1 defa geçiyor.
# pişmanlıklar kelimesi metinde 1 defa geçiyor.
# çekişmeler kelimesi metinde 1 defa geçiyor.
# Raskolnikov’u kelimesi metinde 1 defa geçiyor.
# iyice kelimesi metinde 1 defa geçiyor.
# bitkin kelimesi metinde 1 defa geçiyor.
# düşürür kelimesi metinde 1 defa geçiyor.
# hastalanır kelimesi metinde 1 defa geçiyor.
# İmdadına kelimesi metinde 1 defa geçiyor.
# en kelimesi metinde 2 defa geçiyor.
# yakın kelimesi metinde 1 defa geçiyor.
# arkadaşı kelimesi metinde 1 defa geçiyor.
# Razumikin kelimesi metinde 1 defa geçiyor.
# yetişir kelimesi metinde 1 defa geçiyor.
# Ona kelimesi metinde 1 defa geçiyor.
# destek kelimesi metinde 1 defa geçiyor.
# olur, kelimesi metinde 1 defa geçiyor.
# doktor kelimesi metinde 1 defa geçiyor.
# bulur kelimesi metinde 1 defa geçiyor.
# elinden kelimesi metinde 1 defa geçiyor.
# gelen kelimesi metinde 1 defa geçiyor.
# her kelimesi metinde 1 defa geçiyor.
# şeyi kelimesi metinde 1 defa geçiyor.
# yapar kelimesi metinde 1 defa geçiyor.
# giden kelimesi metinde 1 defa geçiyor.
# durumuna kelimesi metinde 1 defa geçiyor.
# şüphecilik kelimesi metinde 1 defa geçiyor.
# korku kelimesi metinde 1 defa geçiyor.
# eklenir kelimesi metinde 1 defa geçiyor.
# Sürekli kelimesi metinde 1 defa geçiyor.
# birilerinin kelimesi metinde 2 defa geçiyor.
# izlediğini kelimesi metinde 1 defa geçiyor.
# düşünür kelimesi metinde 2 defa geçiyor.
# Cinayeti kelimesi metinde 1 defa geçiyor.
# gördüğü kelimesi metinde 1 defa geçiyor.
# yada kelimesi metinde 1 defa geçiyor.
# azından kelimesi metinde 1 defa geçiyor.
# onun kelimesi metinde 2 defa geçiyor.
# yaptığını kelimesi metinde 1 defa geçiyor.
# bildiğini kelimesi metinde 1 defa geçiyor.
# Bu kelimesi metinde 1 defa geçiyor.
# tedirginlik kelimesi metinde 1 defa geçiyor.
# durumunu kelimesi metinde 1 defa geçiyor.
# sürükler kelimesi metinde 1 defa geçiyor.
# duruma kelimesi metinde 1 defa geçiyor.
# işlediği kelimesi metinde 1 defa geçiyor.
# cinayeti kelimesi metinde 1 defa geçiyor.
# Sonya’ya kelimesi metinde 1 defa geçiyor.
# anlatır kelimesi metinde 1 defa geçiyor.
# Ardından kelimesi metinde 1 defa geçiyor.
# polise kelimesi metinde 1 defa geçiyor.
# teslim kelimesi metinde 1 defa geçiyor.
# olur kelimesi metinde 1 defa geçiyor.
# cezasını kelimesi metinde 1 defa geçiyor.
# çekmek kelimesi metinde 1 defa geçiyor.
# üzere kelimesi metinde 1 defa geçiyor.
# hapse kelimesi metinde 1 defa geçiyor.
# gönderilir kelimesi metinde 1 defa geçiyor.
# Tüm Kelimeler
# en
# *************************************
# pek
# *************************************
# Fakirler
# *************************************
# öğrencidir
# *************************************
# başyapıtı
# *************************************
# yaşlı
# *************************************
# ortadan
# *************************************
# çatışmalara
# *************************************
# cinayet
# *************************************
# yapar
# *************************************
# Dostoyevski’nin
# *************************************
# Ne
# *************************************
# çelişkiler
# *************************************
# altını
# *************************************
# anlam
# *************************************
# fakültesini
# *************************************
# başarılı
# *************************************
# taraftan
# *************************************
# yapacağını
# *************************************
# Yakınlarda
# *************************************
# Ceza
# *************************************
# önemli
# *************************************
# Ona
# *************************************
# bu
# *************************************
# duruma
# *************************************
# yanında
# *************************************
# ondan
# *************************************
# üzere
# *************************************
# getirilmiş
# *************************************
# öğretimini
# *************************************
# bırakmak
# *************************************
# Baltayı
# *************************************
# ölmesi
# *************************************
# kötülüğünün
# *************************************
# meyhanedeki
# *************************************
# bildiğini
# *************************************
# düşünür
# *************************************
# geldiği
# *************************************
# diğer
# *************************************
# hastalanır
# *************************************
# çekişmeler
# *************************************
# kötü
# *************************************
# Ardından
# *************************************
# Petersburg
# *************************************
# durumu
# *************************************
# çekmek
# *************************************
# kalır
# *************************************
# oldukça
# *************************************
# hapse
# *************************************
# olarak
# *************************************
# verek
# *************************************
# arkadaşı
# *************************************
# saatini
# *************************************
# giden
# *************************************
# eklenir
# *************************************
# yada
# *************************************
# yaşamasına
# *************************************
# o
# *************************************
# Dostoyevski
# *************************************
# düşürür
# *************************************
# bulunan
# *************************************
# kafasına
# *************************************
# ve
# *************************************
# kulak
# *************************************
# yayınlanmıştır
# *************************************
# Rusya’nın
# *************************************
# sürükler
# *************************************
# hukuk
# *************************************
# dergisinde
# *************************************
# zararlar
# *************************************
# İmdadına
# *************************************
# Duyduğu
# *************************************
# şeyi
# *************************************
# isimli
# *************************************
# Bir
# *************************************
# orada
# *************************************
# Karşılığında
# *************************************
# birilerinin
# *************************************
# durumunu
# *************************************
# gönderilir
# *************************************
# korku
# *************************************
# kadının
# *************************************
# siyasi
# *************************************
# içerken
# *************************************
# Rus
# *************************************
# gözlemlediği
# *************************************
# Büyük
# *************************************
# sırada
# *************************************
# Okumak
# *************************************
# yakın
# *************************************
# pişmanlıklar
# *************************************
# eline
# *************************************
# ayrıma
# *************************************
# hayatlardan
# *************************************
# kalıcı
# *************************************
# olaylar
# *************************************
# alarak
# *************************************
# filmine
# *************************************
# sonrası
# *************************************
# durumuna
# *************************************
# konu
# *************************************
# iç
# *************************************
# okuyan
# *************************************
# Rusya’da
# *************************************
# ödeyemez
# *************************************
# Raskolnikov
# *************************************
# eser
# *************************************
# vermeye
# *************************************
# başkahramanı
# *************************************
# aldığı
# *************************************
# devam
# *************************************
# azabı
# *************************************
# İşlem:1
# Kelimelerin Frekansı........................
# Dostoyevski kelimesi metinde 1 defa geçiyor.
# Rusya’da kelimesi metinde 1 defa geçiyor.
# yaşanan kelimesi metinde 1 defa geçiyor.
# siyasi kelimesi metinde 1 defa geçiyor.
# ve kelimesi metinde 15 defa geçiyor.
# ekonomik kelimesi metinde 1 defa geçiyor.
# olaylar kelimesi metinde 1 defa geçiyor.
# sonrasında kelimesi metinde 1 defa geçiyor.
# gözlemlediği kelimesi metinde 1 defa geçiyor.
# hayatlardan kelimesi metinde 1 defa geçiyor.
# esinlenerek kelimesi metinde 1 defa geçiyor.
# 1866 kelimesi metinde 1 defa geçiyor.
# yılında kelimesi metinde 1 defa geçiyor.
# yazdığı kelimesi metinde 1 defa geçiyor.
# eser kelimesi metinde 2 defa geçiyor.
# ilk kelimesi metinde 1 defa geçiyor.
# olarak kelimesi metinde 1 defa geçiyor.
# Rus kelimesi metinde 1 defa geçiyor.
# Habercisi kelimesi metinde 1 defa geçiyor.
# isimli kelimesi metinde 1 defa geçiyor.
# edebiyat kelimesi metinde 1 defa geçiyor.
# dergisinde kelimesi metinde 1 defa geçiyor.
# yayınlanmıştır kelimesi metinde 1 defa geçiyor.
# Büyük kelimesi metinde 1 defa geçiyor.
# beğeni kelimesi metinde 1 defa geçiyor.
# toplayan kelimesi metinde 1 defa geçiyor.
# daha kelimesi metinde 7 defa geçiyor.
# sonra kelimesi metinde 1 defa geçiyor.
# kitap kelimesi metinde 2 defa geçiyor.
# haline kelimesi metinde 1 defa geçiyor.
# getirilmiş kelimesi metinde 1 defa geçiyor.
# o kelimesi metinde 2 defa geçiyor.
# günden kelimesi metinde 1 defa geçiyor.
# beri kelimesi metinde 1 defa geçiyor.
# birçok kelimesi metinde 2 defa geçiyor.
# sinema kelimesi metinde 1 defa geçiyor.
# filmine kelimesi metinde 1 defa geçiyor.
# konu kelimesi metinde 1 defa geçiyor.
# olmuştur kelimesi metinde 1 defa geçiyor.
# Suç kelimesi metinde 1 defa geçiyor.
# Ceza kelimesi metinde 1 defa geçiyor.
# Dostoyevski’nin kelimesi metinde 1 defa geçiyor.
# başyapıtı kelimesi metinde 1 defa geçiyor.
# sayılır kelimesi metinde 1 defa geçiyor.
# Kitabın kelimesi metinde 1 defa geçiyor.
# başkahramanı kelimesi metinde 1 defa geçiyor.
# olan kelimesi metinde 4 defa geçiyor.
# Raskolnikov kelimesi metinde 5 defa geçiyor.
# Rusya’nın kelimesi metinde 1 defa geçiyor.
# St kelimesi metinde 2 defa geçiyor.
# Petersburg kelimesi metinde 2 defa geçiyor.
# şehrinde kelimesi metinde 2 defa geçiyor.
# hukuk kelimesi metinde 2 defa geçiyor.
# fakültesinde kelimesi metinde 1 defa geçiyor.
# okuyan kelimesi metinde 1 defa geçiyor.
# başarılı kelimesi metinde 1 defa geçiyor.
# bir kelimesi metinde 5 defa geçiyor.
# öğrencidir kelimesi metinde 1 defa geçiyor.
# Fakir kelimesi metinde 1 defa geçiyor.
# olduğu kelimesi metinde 1 defa geçiyor.
# için kelimesi metinde 2 defa geçiyor.
# hayatını kelimesi metinde 1 defa geçiyor.
# öğretimini kelimesi metinde 1 defa geçiyor.
# devam kelimesi metinde 1 defa geçiyor.
# ettirmekte kelimesi metinde 1 defa geçiyor.
# oldukça kelimesi metinde 1 defa geçiyor.
# zorlanır kelimesi metinde 1 defa geçiyor.
# fakültesini kelimesi metinde 1 defa geçiyor.
# bırakmak kelimesi metinde 1 defa geçiyor.
# zorunda kelimesi metinde 1 defa geçiyor.
# kalır kelimesi metinde 1 defa geçiyor.
# Yaşadığı kelimesi metinde 1 defa geçiyor.
# hayat kelimesi metinde 1 defa geçiyor.
# iç kelimesi metinde 3 defa geçiyor.
# dünyasında kelimesi metinde 1 defa geçiyor.
# kalıcı kelimesi metinde 1 defa geçiyor.
# zararlar kelimesi metinde 1 defa geçiyor.
# vermeye kelimesi metinde 1 defa geçiyor.
# başlar kelimesi metinde 2 defa geçiyor.
# kendi kelimesi metinde 1 defa geçiyor.
# içinde kelimesi metinde 1 defa geçiyor.
# çelişkiye kelimesi metinde 1 defa geçiyor.
# düşmeye kelimesi metinde 1 defa geçiyor.
# Okumak kelimesi metinde 1 defa geçiyor.
# geldiği kelimesi metinde 1 defa geçiyor.
# kirasını kelimesi metinde 1 defa geçiyor.
# ödeyemez kelimesi metinde 1 defa geçiyor.
# Yakınlarda kelimesi metinde 1 defa geçiyor.
# bulunan kelimesi metinde 1 defa geçiyor.
# hiç kelimesi metinde 1 defa geçiyor.
# kimsenin kelimesi metinde 1 defa geçiyor.
# sevmediği kelimesi metinde 1 defa geçiyor.
# tefeci kelimesi metinde 2 defa geçiyor.
# kadına kelimesi metinde 1 defa geçiyor.
# giderek kelimesi metinde 1 defa geçiyor.
# saatini kelimesi metinde 1 defa geçiyor.
# satar kelimesi metinde 1 defa geçiyor.
# Karşılığında kelimesi metinde 1 defa geçiyor.
# aldığı kelimesi metinde 1 defa geçiyor.
# para kelimesi metinde 1 defa geçiyor.
# ile kelimesi metinde 2 defa geçiyor.
# de kelimesi metinde 2 defa geçiyor.
# meyhaneye kelimesi metinde 1 defa geçiyor.
# gider kelimesi metinde 3 defa geçiyor.
# Bir kelimesi metinde 2 defa geçiyor.
# taraftan kelimesi metinde 2 defa geçiyor.
# içerken kelimesi metinde 1 defa geçiyor.
# diğer kelimesi metinde 1 defa geçiyor.
# meyhanedeki kelimesi metinde 1 defa geçiyor.
# insanların kelimesi metinde 1 defa geçiyor.
# hayatları kelimesi metinde 1 defa geçiyor.
# içini kelimesi metinde 1 defa geçiyor.
# da kelimesi metinde 5 defa geçiyor.
# karartır kelimesi metinde 1 defa geçiyor.
# Fakirler kelimesi metinde 1 defa geçiyor.
# zenginler kelimesi metinde 1 defa geçiyor.
# arasında kelimesi metinde 1 defa geçiyor.
# acımasız kelimesi metinde 1 defa geçiyor.
# ayrıma kelimesi metinde 1 defa geçiyor.
# anlam kelimesi metinde 1 defa geçiyor.
# veremez kelimesi metinde 1 defa geçiyor.
# içindeki kelimesi metinde 2 defa geçiyor.
# çatışmalara kelimesi metinde 1 defa geçiyor.
# fazla kelimesi metinde 2 defa geçiyor.
# dayanamaz kelimesi metinde 2 defa geçiyor.
# şeytana kelimesi metinde 1 defa geçiyor.
# kulak kelimesi metinde 1 defa geçiyor.
# verek kelimesi metinde 1 defa geçiyor.
# eline kelimesi metinde 1 defa geçiyor.
# balta kelimesi metinde 1 defa geçiyor.
# alarak kelimesi metinde 2 defa geçiyor.
# kadının kelimesi metinde 4 defa geçiyor.
# evine kelimesi metinde 1 defa geçiyor.
# Baltayı kelimesi metinde 1 defa geçiyor.
# kafasına kelimesi metinde 1 defa geçiyor.
# indirerek kelimesi metinde 1 defa geçiyor.
# onu kelimesi metinde 3 defa geçiyor.
# orada kelimesi metinde 1 defa geçiyor.
# öldürür kelimesi metinde 2 defa geçiyor.
# Tam kelimesi metinde 1 defa geçiyor.
# bu kelimesi metinde 2 defa geçiyor.
# sırada kelimesi metinde 1 defa geçiyor.
# yaşlı kelimesi metinde 1 defa geçiyor.
# kız kelimesi metinde 1 defa geçiyor.
# kardeşi kelimesi metinde 1 defa geçiyor.
# gelir kelimesi metinde 1 defa geçiyor.
# anda kelimesi metinde 1 defa geçiyor.
# Tefeci kelimesi metinde 1 defa geçiyor.
# kötülüğünün kelimesi metinde 1 defa geçiyor.
# yanında kelimesi metinde 1 defa geçiyor.
# masumun kelimesi metinde 1 defa geçiyor.
# ölmesi kelimesi metinde 1 defa geçiyor.
# pek kelimesi metinde 1 defa geçiyor.
# önemli kelimesi metinde 1 defa geçiyor.
# ...
# ayrıma kelimesi metinde 1 defa geçiyor.
# anlam kelimesi metinde 1 defa geçiyor.
# veremez kelimesi metinde 1 defa geçiyor.
# içindeki kelimesi metinde 2 defa geçiyor.
# çatışmalara kelimesi metinde 1 defa geçiyor.
# fazla kelimesi metinde 2 defa geçiyor.
# dayanamaz kelimesi metinde 2 defa geçiyor.
# şeytana kelimesi metinde 1 defa geçiyor.
# kulak kelimesi metinde 1 defa geçiyor.
# verek kelimesi metinde 1 defa geçiyor.
# eline kelimesi metinde 1 defa geçiyor.
# balta kelimesi metinde 1 defa geçiyor.
# alarak kelimesi metinde 2 defa geçiyor.
# kadının kelimesi metinde 4 defa geçiyor.
# evine kelimesi metinde 1 defa geçiyor.
# Baltayı kelimesi metinde 1 defa geçiyor.
# kafasına kelimesi metinde 1 defa geçiyor.
# indirerek kelimesi metinde 1 defa geçiyor.
# onu kelimesi metinde 3 defa geçiyor.
# orada kelimesi metinde 1 defa geçiyor.
# öldürür kelimesi metinde 2 defa geçiyor.
# Tam kelimesi metinde 1 defa geçiyor.
# bu kelimesi metinde 2 defa geçiyor.
# sırada kelimesi metinde 1 defa geçiyor.
# yaşlı kelimesi metinde 1 defa geçiyor.
# kız kelimesi metinde 1 defa geçiyor.
# kardeşi kelimesi metinde 1 defa geçiyor.
# gelir kelimesi metinde 1 defa geçiyor.
# anda kelimesi metinde 1 defa geçiyor.
# Tefeci kelimesi metinde 1 defa geçiyor.
# kötülüğünün kelimesi metinde 1 defa geçiyor.
# yanında kelimesi metinde 1 defa geçiyor.
# masumun kelimesi metinde 1 defa geçiyor.
# ölmesi kelimesi metinde 1 defa geçiyor.
# pek kelimesi metinde 1 defa geçiyor.
# önemli kelimesi metinde 1 defa geçiyor.
# değildir kelimesi metinde 1 defa geçiyor.
# Ne kelimesi metinde 1 defa geçiyor.
# yapacağını kelimesi metinde 1 defa geçiyor.
# bilmeden kelimesi metinde 1 defa geçiyor.
# birkaç kelimesi metinde 1 defa geçiyor.
# altını kelimesi metinde 1 defa geçiyor.
# oradan kelimesi metinde 1 defa geçiyor.
# uzaklaştı kelimesi metinde 1 defa geçiyor.
# İşlediği kelimesi metinde 1 defa geçiyor.
# cinayet kelimesi metinde 1 defa geçiyor.
# sonrası kelimesi metinde 1 defa geçiyor.
# Raskolnikov’un kelimesi metinde 2 defa geçiyor.
# durumu kelimesi metinde 1 defa geçiyor.
# kötüye kelimesi metinde 3 defa geçiyor.
# zamanlar kelimesi metinde 1 defa geçiyor.
# çelişkiler kelimesi metinde 1 defa geçiyor.
# yaşamasına kelimesi metinde 1 defa geçiyor.
# neden kelimesi metinde 1 defa geçiyor.
# şeytan kelimesi metinde 1 defa geçiyor.
# ortadan kelimesi metinde 1 defa geçiyor.
# kaybolmuş kelimesi metinde 1 defa geçiyor.
# fakat kelimesi metinde 1 defa geçiyor.
# ondan kelimesi metinde 1 defa geçiyor.
# kötü kelimesi metinde 1 defa geçiyor.
# vicdan kelimesi metinde 1 defa geçiyor.
# azabı kelimesi metinde 1 defa geçiyor.
# gelmiştir kelimesi metinde 1 defa geçiyor.
# Duyduğu kelimesi metinde 1 defa geçiyor.
# pişmanlıklar kelimesi metinde 1 defa geçiyor.
# çekişmeler kelimesi metinde 1 defa geçiyor.
# Raskolnikov’u kelimesi metinde 1 defa geçiyor.
# iyice kelimesi metinde 1 defa geçiyor.
# bitkin kelimesi metinde 1 defa geçiyor.
# düşürür kelimesi metinde 1 defa geçiyor.
# hastalanır kelimesi metinde 1 defa geçiyor.
# İmdadına kelimesi metinde 1 defa geçiyor.
# en kelimesi metinde 2 defa geçiyor.
# yakın kelimesi metinde 1 defa geçiyor.
# arkadaşı kelimesi metinde 1 defa geçiyor.
# Razumikin kelimesi metinde 1 defa geçiyor.
# yetişir kelimesi metinde 1 defa geçiyor.
# Ona kelimesi metinde 1 defa geçiyor.
# destek kelimesi metinde 1 defa geçiyor.
# olur, kelimesi metinde 1 defa geçiyor.
# doktor kelimesi metinde 1 defa geçiyor.
# bulur kelimesi metinde 1 defa geçiyor.
# elinden kelimesi metinde 1 defa geçiyor.
# gelen kelimesi metinde 1 defa geçiyor.
# her kelimesi metinde 1 defa geçiyor.
# şeyi kelimesi metinde 1 defa geçiyor.
# yapar kelimesi metinde 1 defa geçiyor.
# giden kelimesi metinde 1 defa geçiyor.
# durumuna kelimesi metinde 1 defa geçiyor.
# şüphecilik kelimesi metinde 1 defa geçiyor.
# korku kelimesi metinde 1 defa geçiyor.
# eklenir kelimesi metinde 1 defa geçiyor.
# Sürekli kelimesi metinde 1 defa geçiyor.
# birilerinin kelimesi metinde 2 defa geçiyor.
# izlediğini kelimesi metinde 1 defa geçiyor.
# düşünür kelimesi metinde 2 defa geçiyor.
# Cinayeti kelimesi metinde 1 defa geçiyor.
# gördüğü kelimesi metinde 1 defa geçiyor.
# yada kelimesi metinde 1 defa geçiyor.
# azından kelimesi metinde 1 defa geçiyor.
# onun kelimesi metinde 2 defa geçiyor.
# yaptığını kelimesi metinde 1 defa geçiyor.
# bildiğini kelimesi metinde 1 defa geçiyor.
# Bu kelimesi metinde 1 defa geçiyor.
# tedirginlik kelimesi metinde 1 defa geçiyor.
# durumunu kelimesi metinde 1 defa geçiyor.
# sürükler kelimesi metinde 1 defa geçiyor.
# duruma kelimesi metinde 1 defa geçiyor.
# işlediği kelimesi metinde 1 defa geçiyor.
# cinayeti kelimesi metinde 1 defa geçiyor.
# Sonya’ya kelimesi metinde 1 defa geçiyor.
# anlatır kelimesi metinde 1 defa geçiyor.
# Ardından kelimesi metinde 1 defa geçiyor.
# polise kelimesi metinde 1 defa geçiyor.
# teslim kelimesi metinde 1 defa geçiyor.
# olur kelimesi metinde 1 defa geçiyor.
# cezasını kelimesi metinde 1 defa geçiyor.
# çekmek kelimesi metinde 1 defa geçiyor.
